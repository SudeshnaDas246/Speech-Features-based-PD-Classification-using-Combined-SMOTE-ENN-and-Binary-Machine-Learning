# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (7, 5)

# %% [markdown]
# ##Data Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import KernelPCA
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import plot_precision_recall_curve
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.metrics import auc
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
parkinsons_data = pd.read_csv('pd_speech_features.csv')

# %%
parkinsons_data.head()
# Out:
#    id  gender  ...  tqwt_kurtosisValue_dec_36  class
# 0   0       1  ...                    18.9405      1
# 1   0       1  ...                    45.1780      1
# 2   0       1  ...                     4.7666      1
# 3   1       0  ...                     4.0603      1
# 4   1       0  ...                     6.1164      1
#
# [5 rows x 755 columns]

# %%
parkinsons_data.shape
# Out:
# (756, 755)

# %%
parkinsons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Columns: 755 entries, id to class
# dtypes: float64(749), int64(6)
# memory usage: 4.4 MB

# %%
parkinsons_data.isnull().sum()
# Out:
# id                           0
# gender                       0
# PPE                          0
# DFA                          0
# RPDE                         0
#                             ..
# tqwt_kurtosisValue_dec_33    0
# tqwt_kurtosisValue_dec_34    0
# tqwt_kurtosisValue_dec_35    0
# tqwt_kurtosisValue_dec_36    0
# class                        0
# Length: 755, dtype: int64

# %%
parkinsons_data.describe()
# Out:
#                id      gender  ...  tqwt_kurtosisValue_dec_36       class
# count  756.000000  756.000000  ...                 756.000000  756.000000
# mean   125.500000    0.515873  ...                  31.481110    0.746032
# std     72.793721    0.500079  ...                  34.230991    0.435568
# min      0.000000    0.000000  ...                   2.364000    0.000000
# 25%     62.750000    0.000000  ...                   3.948750    0.000000
# 50%    125.500000    1.000000  ...                  10.637250    1.000000
# 75%    188.250000    1.000000  ...                  61.125325    1.000000
# max    251.000000    1.000000  ...                 156.423700    1.000000
#
# [8 rows x 755 columns]

# %%
parkinsons_data['class'].value_counts()
# Out:
# 1    564
# 0    192
# Name: class, dtype: int64

# %%
X = parkinsons_data.drop(columns=['id','class'], axis=1)
#X = parkinsons_data.iloc[:,322:754]
#X = parkinsons_data.iloc[:,2:23]
Y = parkinsons_data['class']

# %%
X
# Out:
#      gender      PPE  ...  tqwt_kurtosisValue_dec_35  tqwt_kurtosisValue_dec_36
# 0         1  0.85247  ...                     3.0004                    18.9405
# 1         1  0.76686  ...                     6.3431                    45.1780
# 2         1  0.85083  ...                     3.1495                     4.7666
# 3         0  0.41121  ...                     6.2650                     4.0603
# 4         0  0.32790  ...                     5.0559                     6.1164
# ..      ...      ...  ...                        ...                        ...
# 751       0  0.80903  ...                     3.2003                     6.8671
# 752       0  0.16084  ...                    10.9058                    28.4170
# 753       0  0.88389  ...                     3.3545                     5.0424
# 754       0  0.83782  ...                     2.8332                     3.7131
# 755       0  0.81304  ...                     2.6217                     3.1527
#
# ...

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 751    0
# 752    0
# 753    0
# 754    0
# 755    0
# Name: class, Length: 756, dtype: int64

# %% [markdown]
# ## Resampling

# %%
np.count_nonzero(Y == 1), np.count_nonzero(Y == 0)
# Out:
# (564, 192)

# %%
from imblearn.combine import SMOTEENN 


sm = SMOTEENN(random_state=6)

X, Y = sm.fit_resample(X, Y.ravel())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
# ...

# %%
X.shape, Y.shape, np.count_nonzero(Y == 1), np.count_nonzero(Y == 0)
# Out:
# ((458, 753), (458,), 217, 241)

# %% [markdown]
# ##Standardization

# %%
scaler = StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X = scaler.transform(X)

# %% [markdown]
# ## Dimensionality Reduction

# %%
principal=KernelPCA(kernel = 'cosine', n_components = 168)
principal.fit(X)
X=principal.transform(X)
X.shape
# Out:
# (458, 168)

# %% [markdown]
# ##XGBOOST

# %%
#classifier = XGBClassifier(max_depth = 10,learning_rate=0.3, scale_pos_weight=3,base_score=0.3,colsample_bytree=0.8, min_child_weight=2)
classifier = XGBClassifier(learning_rate=0.3,min_child_weight=2)
classifier
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.3, max_delta_step=0, max_depth=3,
#               min_child_weight=2, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
scoring = {'acc': 'accuracy',
           'prec': 'precision',
           'rec': 'recall',
           'f1' : 'f1',
           'auc': 'roc_auc'
           }
scores_xgb = cross_validate(classifier, X, Y, scoring=scoring,
                         cv=10)

for k in ['test_acc','test_prec', 'test_rec','test_f1','test_auc']:
    scores_xgb[k] = round((scores_xgb[k].mean())*100,4)
    print(k,scores_xgb[k])
# Out:
# test_acc 91.9227
# test_prec 93.4154
# test_rec 89.3723
# test_f1 91.1872
# test_auc 97.881

# %%
cv = StratifiedKFold(n_splits=10, random_state = 0)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()

for i, (train, test) in enumerate(cv.split(X, Y)):
    classifier.fit(X[train], Y[train])
    viz = plot_roc_curve(classifier, X[test], Y[test],
                         name='ROC fold {}'.format(i),
                         alpha=0.5, lw=1.5, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=3, alpha=1)

mean_tpr_xgb, mean_fpr_xgb = mean_tpr, mean_fpr

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="Receiver operating characteristic - XGBoost")
#ax.legend(loc="lower right") 
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# ##RANDOM FOREST

# %%
classifier = RandomForestClassifier(random_state = 3, max_depth = 16,n_estimators=150,max_features=0.2)
classifier
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=16, max_features=0.2,
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=150,
#                        n_jobs=None, oob_score=False, random_state=3, verbose=0,
#                        warm_start=False)

# %%
scoring = {'acc': 'accuracy',
           'prec': 'precision',
           'rec': 'recall',
           'f1' : 'f1',
           'auc': 'roc_auc'
           }
scores_rf = cross_validate(classifier, X, Y, scoring=scoring,
                         cv=10)

for k in ['test_acc','test_prec', 'test_rec','test_f1','test_auc']:
    scores_rf[k] = round((scores_rf[k].mean())*100,4)
    print(k,scores_rf[k])
# Out:
# test_acc 94.5459
# test_prec 94.6226
# test_rec 94.0476
# test_f1 94.1915
# test_auc 98.8201

# %%
cv = StratifiedKFold(n_splits=10, random_state = 0)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()

for i, (train, test) in enumerate(cv.split(X, Y)):
    classifier.fit(X[train], Y[train])
    viz = plot_roc_curve(classifier, X[test], Y[test],
                         name='ROC fold {}'.format(i),
                         alpha=0.5, lw=1.5, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=3, alpha=1)

mean_tpr_rf, mean_fpr_rf = mean_tpr, mean_fpr

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="Receiver operating characteristic - Random Forest")
#ax.legend(loc="lower right") 
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# ##KNN

# %%
classifier = KNeighborsClassifier(n_neighbors=3)
classifier
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
scoring = {'acc': 'accuracy',
           'prec': 'precision',
           'rec': 'recall',
           'f1' : 'f1',
           'auc': 'roc_auc'
           }
scores_knn = cross_validate(classifier, X, Y, scoring=scoring,
                         cv=10)

for k in ['test_acc','test_prec', 'test_rec','test_f1','test_auc']:
    scores_knn[k] = round((scores_knn[k].mean())*100,4)
    print(k,scores_knn[k])
# Out:
# test_acc 93.6618
# test_prec 97.481
# test_rec 88.8745
# test_f1 92.8379
# test_auc 97.0397

# %%
cv = StratifiedKFold(n_splits=10, random_state = 0)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()

for i, (train, test) in enumerate(cv.split(X, Y)):
    classifier.fit(X[train], Y[train])
    viz = plot_roc_curve(classifier, X[test], Y[test],
                         name='ROC fold {}'.format(i),
                         alpha=0.5, lw=1.5, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=3, alpha=1)

mean_tpr_knn, mean_fpr_knn = mean_tpr, mean_fpr

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="Receiver operating characteristic - KNN")
#ax.legend(loc="lower right") 
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# ##SVM

# %%
classifier = SVC(kernel = 'rbf')
classifier
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
scoring = {'acc': 'accuracy',
           'prec': 'precision',
           'rec': 'recall',
           'f1': 'f1',
           'auc': 'roc_auc'
           }
scores_svm = cross_validate(classifier, X, Y, scoring=scoring,
                         cv=10)

for k in ['test_acc','test_prec', 'test_rec','test_f1','test_auc']:
    scores_svm[k] = round((scores_svm[k].mean())*100,4)
    print(k,scores_svm[k])
# Out:
# test_acc 96.5024
# test_prec 96.4078
# test_rec 96.2771
# test_f1 96.2844
# test_auc 99.251

# %%
cv = StratifiedKFold(n_splits=10, random_state = 0)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()

for i, (train, test) in enumerate(cv.split(X, Y)):
    classifier.fit(X[train], Y[train])
    viz = plot_roc_curve(classifier, X[test], Y[test],
                         name='ROC fold {}'.format(i),
                         alpha=0.5, lw=1.5, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=3, alpha=1)

mean_tpr_svm, mean_fpr_svm = mean_tpr, mean_fpr

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="Receiver operating characteristic - SVM")
#ax.legend(loc="lower right") 
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# ##Logistic Regression

# %%
classifier = LogisticRegression(max_iter = 200)
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
scoring = {'acc': 'accuracy',
           'prec': 'precision',
           'rec': 'recall',
           'f1':'f1',
           'auc': 'roc_auc'
           }
scores_lr = cross_validate(classifier, X, Y, scoring=scoring,
                         cv=10)

for k in ['test_acc','test_prec', 'test_rec','test_f1','test_auc']:
    scores_lr[k] = round((scores_lr[k].mean())*100,4)
    print(k,scores_lr[k])
# Out:
# test_acc 87.9855
# test_prec 88.1624
# test_rec 87.0779
# test_f1 87.2844
# test_auc 94.9706

# %%
cv = StratifiedKFold(n_splits=10, random_state = 0)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()

for i, (train, test) in enumerate(cv.split(X, Y)):
    classifier.fit(X[train], Y[train])
    viz = plot_roc_curve(classifier, X[test], Y[test],
                         name='ROC fold {}'.format(i),
                         alpha=0.5, lw=1.5, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=3, alpha=1)

mean_tpr_lr, mean_fpr_lr = mean_tpr, mean_fpr

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="Receiver operating characteristic - Logistic Regression")
#ax.legend(loc="lower right") 
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# ##Decision Tree

# %%
classifier = DecisionTreeClassifier(random_state=0)
classifier
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
scoring = {'acc': 'accuracy',
           'prec': 'precision',
           'rec': 'recall',
           'f1':'f1',
           'auc': 'roc_auc'
           }
scores_dt = cross_validate(classifier, X, Y, scoring=scoring,
                         cv=10)

for k in ['test_acc','test_prec', 'test_rec','test_f1','test_auc']:
    scores_dt[k] = round((scores_dt[k].mean())*100,4)
    print(k,scores_dt[k])
# Out:
# test_acc 84.3043
# test_prec 87.8529
# test_rec 77.9221
# test_f1 82.1719
# test_auc 83.9944

# %%
cv = StratifiedKFold(n_splits=10, random_state = 0)

tprs = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)

fig, ax = plt.subplots()

for i, (train, test) in enumerate(cv.split(X, Y)):
    classifier.fit(X[train], Y[train])
    viz = plot_roc_curve(classifier, X[test], Y[test],
                         name='ROC fold {}'.format(i),
                         alpha=0.5, lw=1.5, ax=ax)
    interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    aucs.append(viz.roc_auc)

ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
        label='Chance', alpha=.8)

mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
ax.plot(mean_fpr, mean_tpr, color='b',
        label=r'Mean ROC (AUC = %0.2f)' % (mean_auc),
        lw=3, alpha=1)

mean_tpr_dt, mean_fpr_dt = mean_tpr, mean_fpr

ax.set(xlim=[-0.05, 1.05], ylim=[-0.05, 1.05],
       title="Receiver operating characteristic- Decision Tree")
#ax.legend(loc="lower right")
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %% [markdown]
# ##Total scores

# %%
results = [scores_xgb, scores_svm,scores_rf,scores_lr, scores_knn, scores_dt]

res = pd.DataFrame(results)
res = res.drop(columns=['fit_time','score_time'], axis=1)
res.index = ['XGB', 'SVM', 'RF', 'LR','KNN', 'DT']
res.columns = ['Accuracy', 'Recall', 'Precision','F1 Score', 'AUC']

#res.to_csv(index=False)
res
# Out:
#      Accuracy   Recall  Precision  F1 Score      AUC
# XGB   91.9227  93.4154    89.3723   91.1872  97.8810
# SVM   96.5024  96.4078    96.2771   96.2844  99.2510
# RF    94.5459  94.6226    94.0476   94.1915  98.8201
# LR    87.9855  88.1624    87.0779   87.2844  94.9706
# KNN   93.6618  97.4810    88.8745   92.8379  97.0397
# DT    84.3043  87.8529    77.9221   82.1719  83.9944
